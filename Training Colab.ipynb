# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Installing extra packages
#
# PyTorch Lightning have to be installed for this solution

# %%
# %%capture
# !pip install git+https://github.com/PytorchLightning/pytorch-lightning.git@1.0.0rc4

# !pip install efficientnet_pytorch

# %% [markdown]
# # Preparing data
#
# In this notebook I'm going to use [Dogs dataset](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/dogImages.zip)
#
# Download the dataset and unzip it to the notebook's home.

# %%
# !wget https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/dogImages.zip

# !unzip dogImages.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: dogImages/train/048.Chihuahua/Chihuahua_03418.jpg
#   inflating: dogImages/train/048.Chihuahua/Chihuahua_03421.jpg
#   inflating: dogImages/train/048.Chihuahua/Chihuahua_03423.jpg
#   inflating: dogImages/train/048.Chihuahua/Chihuahua_03424.jpg
#   inflating: dogImages/train/048.Chihuahua/Chihuahua_03425.jpg
#   inflating: dogImages/train/048.Chihuahua/Chihuahua_03426.jpg
#   inflating: dogImages/train/048.Chihuahua/Chihuahua_03428.jpg
#   inflating: dogImages/train/048.Chihuahua/Chihuahua_03429.jpg
#   inflating: dogImages/train/048.Chihuahua/Chihuahua_03430.jpg
#   inflating: dogImages/train/048.Chihuahua/Chihuahua_03431.jpg
#   inflating: dogImages/train/048.Chihuahua/Chihuahua_03432.jpg
#   inflating: dogImages/train/048.Chihuahua/Chihuahua_03433.jpg
#   inflating: dogImages/train/048.Chihuahua/Chihuahua_03434.jpg
#   inflating: dogImages/train/048.Chihuahua/Chihuahua_03435.jpg
# ...

# %%
import torch.nn as nn
from pytorch_lightning import Trainer

from datamodule import DogsDataModule
from net import DogsBreedClassifier
from net_transfer_densenet121 import DogsBreedClassifierDenseNet
from net_transfer_EfficientNet import DogsBreedClassifierEfficientNet

from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True

# %%
paths = {
    'train': './dogImages/train/',
    'test': './dogImages/test/',
    'val': './dogImages/valid/'
}

dm = DogsDataModule(paths)

# %%
model = DogsBreedClassifier()

trainer = Trainer(gpus=1, max_epochs=20, default_root_dir='scratch_model_logs')

trainer.fit(model, dm)
# Out:
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#    | Name      | Type        | Params
# -------------------------------------------
# 0  | conv1     | Conv2d      | 896
# 1  | conv2     | Conv2d      | 18 K
# 2  | conv3     | Conv2d      | 73 K
# 3  | conv4     | Conv2d      | 295 K
# 4  | pool      | MaxPool2d   | 0
# 5  | fc1       | Linear      | 6 M
# 6  | fc2       | Linear      | 68 K
# 7  | dropout   | Dropout     | 0
# 8  | bn1       | BatchNorm2d | 64
# 9  | bn2       | BatchNorm2d | 128
# 10 | bn3       | BatchNorm2d | 256
# 11 | bn4       | BatchNorm2d | 512
# 12 | fcbn1     | BatchNorm1d | 25 K
# 13 | fcbn2     | BatchNorm1d | 1 K
# 14 | train_acc | Accuracy    | 0
# 15 | val_acc   | Accuracy    | 0
# ...
# 1

# %%
# !zip -r scratch_model_logs.zip scratch_model_logs/

# !cp scratch_model_logs.zip /content/drive/My\ Drive/Colab\ Notebooks/

# !rm scratch_model_logs.zip
# Out:
#   adding: scratch_model_logs/ (stored 0%)
#   adding: scratch_model_logs/lightning_logs/ (stored 0%)
#   adding: scratch_model_logs/lightning_logs/version_0/ (stored 0%)
#   adding: scratch_model_logs/lightning_logs/version_0/hparams.yaml (stored 0%)
#   adding: scratch_model_logs/lightning_logs/version_0/events.out.tfevents.1602472078.9d7f372088f3.99.0 (deflated 73%)
#   adding: scratch_model_logs/lightning_logs/version_0/checkpoints/ (stored 0%)
#   adding: scratch_model_logs/lightning_logs/version_0/checkpoints/epoch=14.ckpt (deflated 9%)

# %%
model = DogsBreedClassifierDenseNet()

trainer = Trainer(gpus=1, max_epochs=5, default_root_dir='transfer_densenet_logs')

trainer.fit(model, dm)
# Out:
# Downloading: "https://download.pytorch.org/models/densenet121-a639ec97.pth" to /root/.cache/torch/hub/checkpoints/densenet121-a639ec97.pth
# ...
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name      | Type     | Params
# ---------------------------------------
# 0 | model     | DenseNet | 7 M
# 1 | train_acc | Accuracy | 0
# 2 | val_acc   | Accuracy | 0
# ...
# 1

# %%
# !zip -r transfer_densenet_logs.zip transfer_densenet_logs/

# !cp transfer_densenet_logs.zip /content/drive/My\ Drive/Colab\ Notebooks/

# !rm transfer_densenet_logs.zip
# Out:
#   adding: transfer_densenet_logs/ (stored 0%)
#   adding: transfer_densenet_logs/lightning_logs/ (stored 0%)
#   adding: transfer_densenet_logs/lightning_logs/version_0/ (stored 0%)
#   adding: transfer_densenet_logs/lightning_logs/version_0/hparams.yaml (stored 0%)
#   adding: transfer_densenet_logs/lightning_logs/version_0/events.out.tfevents.1602473711.9d7f372088f3.99.1 (deflated 71%)
#   adding: transfer_densenet_logs/lightning_logs/version_0/checkpoints/ (stored 0%)
#   adding: transfer_densenet_logs/lightning_logs/version_0/checkpoints/epoch=4.ckpt (deflated 7%)

# %%
dm = DogsDataModule(paths)

model = DogsBreedClassifierEfficientNet()

trainer = Trainer(gpus=1, max_epochs=5, default_root_dir='transfer_efficientnet_logs')

trainer.fit(model, dm)
# Out:
# Downloading: "https://github.com/lukemelas/EfficientNet-PyTorch/releases/download/1.0/efficientnet-b6-c76e70fd.pth" to /root/.cache/torch/hub/checkpoints/efficientnet-b6-c76e70fd.pth
# ...
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name      | Type         | Params
# -------------------------------------------
# 0 | model     | EfficientNet | 41 M
# 1 | train_acc | Accuracy     | 0
# 2 | val_acc   | Accuracy     | 0
# Loaded pretrained weights for efficientnet-b6
# ...
# 1

# %%
# !zip -r transfer_efficientnet_logs.zip transfer_efficientnet_logs/

# !cp transfer_efficientnet_logs.zip /content/drive/My\ Drive/Colab\ Notebooks/

# !rm transfer_efficientnet_logs.zip
# Out:
#   adding: transfer_efficientnet_logs/ (stored 0%)
#   adding: transfer_efficientnet_logs/lightning_logs/ (stored 0%)
#   adding: transfer_efficientnet_logs/lightning_logs/version_0/ (stored 0%)
#   adding: transfer_efficientnet_logs/lightning_logs/version_0/hparams.yaml (stored 0%)
#   adding: transfer_efficientnet_logs/lightning_logs/version_0/events.out.tfevents.1602474123.9d7f372088f3.99.2 (deflated 71%)
#   adding: transfer_efficientnet_logs/lightning_logs/version_0/checkpoints/ (stored 0%)
#   adding: transfer_efficientnet_logs/lightning_logs/version_0/checkpoints/epoch=4.ckpt (deflated 7%)
